# %%
import argparse

import tensorflow as tf
from tensorflow import keras

from utils import get_datasets, get_module_logger, display_metrics

# %%
def create_network():
    """ output a keras model """
    model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(32, 32, 3)),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(43)])
    return model

# %%
epochs = 10
imdir = '../GTSRB/Final_Training/Images'

train_dataset, val_dataset = get_datasets(imdir)

model = create_network()

model.compile(optimizer='adam',
          loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
          metrics=['accuracy'])

history = model.fit(x=train_dataset, 
                    epochs=epochs, 
                    validation_data=val_dataset)
display_metrics(history)
# Out:
# Found 4300 files belonging to 43 classes.
# Using 3440 files for training.
# Found 4300 files belonging to 43 classes.
# Using 860 files for validation.
# Epoch 1/10
# 14/14 [==============================] - 1s 18ms/step - loss: 3.7531 - accuracy: 0.0497 - val_loss: 3.5980 - val_accuracy: 0.0767
# Epoch 2/10
# 14/14 [==============================] - 0s 11ms/step - loss: 3.4948 - accuracy: 0.1166 - val_loss: 3.3886 - val_accuracy: 0.1651
# Epoch 3/10
# 14/14 [==============================] - 0s 11ms/step - loss: 3.2738 - accuracy: 0.1968 - val_loss: 3.1874 - val_accuracy: 0.2198
# Epoch 4/10
# 14/14 [==============================] - 0s 11ms/step - loss: 3.0792 - accuracy: 0.2555 - val_loss: 2.9747 - val_accuracy: 0.2744
# Epoch 5/10
# 14/14 [==============================] - 0s 11ms/step - loss: 2.8636 - accuracy: 0.3244 - val_loss: 2.7768 - val_accuracy: 0.3512
# Epoch 6/10
# 14/14 [==============================] - 0s 11ms/step - loss: 2.6792 - accuracy: 0.3892 - val_loss: 2.6480 - val_accuracy: 0.3884
# Epoch 7/10
# 14/14 [==============================] - 0s 11ms/step - loss: 2.5106 - accuracy: 0.4442 - val_loss: 2.4838 - val_accuracy: 0.4174
# Epoch 8/10
# 14/14 [==============================] - 0s 13ms/step - loss: 2.3771 - accuracy: 0.4648 - val_loss: 2.3667 - val_accuracy: 0.4477
# Epoch 9/10
# 14/14 [==============================] - 0s 11ms/step - loss: 2.2369 - accuracy: 0.5137 - val_loss: 2.2592 - val_accuracy: 0.4709
# Epoch 10/10
# 14/14 [==============================] - 0s 11ms/step - loss: 2.1255 - accuracy: 0.5302 - val_loss: 2.1523 - val_accuracy: 0.5128
